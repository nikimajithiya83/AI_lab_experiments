# %% [markdown]
# <a href="https://colab.research.google.com/github/nikimajithiya83/AI_lab_experiments/blob/main/Textrank_keywordextraction_postlab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text="""Iam Niki Majithiya, a student of Btech in ICT at Marwadi University India.
I intent to have a strong interest in VLSI technology, circuit building and debugging.
I enjoy working on projects that help me improve my knowledge in circuit building and designing.
My academic journey has helped me develop a solid foundation in programming, electronics and analytical thinking.
I have worked with PHP, MySQL and frontend tools for building a website.
One of my projects that I built using this technology includes an event management system where I handled backend development and database design.
I am also exploring IoT-based systems and microcontrollers like AVR and ESP modules, aiming to build efficient and reliable real-world solutions.
I am specifically interested in solving problems that involve automation and optimization.
For example, I have worked on concepts involving sensor-based systems and attendance tracking solutions.
 I try to focus on making systems that are efficient, scalable and user-friendly.
Besides technical skills, I value logical thinking and structured problem-solving that can help me enhance my skills in electronics.
I continuously try to improve my skills in Verilog and VLSI design as it is main area of interest."""

# %%
#importing basic libraries
import nltk
import networkx as nx
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

# %%
#downloading requirements
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
def textrank_keyword(text,topn=5,window_size=4):
  words=word_tokenize(text.lower())
  stop_words=set(stopwords.words('english'))
  words=[w for w in words if w not in stop_words and w not in string.punctuation]
  graph=nx.Graph()

  for i,word in enumerate(words):
    for j in range(i+1,i+window_size):
      if (j<len(words)):
        graph.add_edge(word,words[j])

  scores=nx.pagerank(graph)
  ranked_words=sorted(scores.items(),key=lambda x:x[1], reverse=True)
  keywords=[word for word, score in ranked_words[:topn]]
  return keywords

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
print(textrank_keyword(text))
# Out:
# ['systems', 'building', 'skills', 'design', 'efficient']
