# %% [markdown]
# <a href="https://colab.research.google.com/github/nikimajithiya83/AI_lab_experiments/blob/main/Word_embeddings_postlab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sentences=[
     "India is the 4th largest economy in the world. India has a huge population of 1.4 billion people making it the world's most populated country surpassing China.",
     "Football is a good and interesting sport. I grew up watching football.",
     "India is highly advance in Science and Technology. India is emerging in the field of VLSI. VLSI is the manufacturing of semiconductors used in all electronic devices."
     ]

# %%
#importing libraries
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer  #TF-BoW
from sklearn.feature_extraction.text import TfidfVectorizer  #TF-IDF
from sklearn.metrics.pairwise import cosine_similarity

# %%
#Embeddings using TF-BoW approach
tf_vectorizer = CountVectorizer()
tf_matrix = tf_vectorizer.fit_transform(sentences)

# %%
tf_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 49 stored elements and shape (3, 42)>

# %%
tf_similarity=cosine_similarity(tf_matrix)
tf_similarity
# Out:
# array([[1.        , 0.048795  , 0.44380231],
#        [0.048795  , 1.        , 0.16843038],
#        [0.44380231, 0.16843038, 1.        ]])

# %%
#Embeddings using TF-IDF approach
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(sentences)

# %%
tfidf_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 49 stored elements and shape (3, 42)>

# %%
tfidf_similarity=cosine_similarity(tfidf_matrix)
tfidf_similarity
# Out:
# array([[1.        , 0.01993353, 0.32535212],
#        [0.01993353, 1.        , 0.08707931],
#        [0.32535212, 0.08707931, 1.        ]])

# %%
#finding out the document similarity
def doc_sim(similarity_matrix,sentences):
  for i in range(len(sentences)):
    sims=similarity_matrix[i].copy()
    sims[i]=-1         #excludes the sentences that is being compared with the rest of the sentences
    top_index=np.argmax(sims)
    print(sentences[i],"--->",sentences[top_index])

# %%
print("\n Document Similarity using TF-BoW Vectorization")
doc_sim(tf_similarity,sentences)

print("\n Document Similarity using TF-IDF Vectorization")
doc_sim(tfidf_similarity,sentences)
# Out:
#  Document Similarity using TF-BoW Vectorization
# India is the 4th largest economy in the world. India has a huge population of 1.4 billion people making it the world's most populated country surpassing China. ---> India is highly advance in Science and Technology. India is emerging in the field of VLSI. VLSI is the manufacturing of semiconductors used in all electronic devices.
# Football is a good and interesting sport. I grew up watching football. ---> India is highly advance in Science and Technology. India is emerging in the field of VLSI. VLSI is the manufacturing of semiconductors used in all electronic devices.
# India is highly advance in Science and Technology. India is emerging in the field of VLSI. VLSI is the manufacturing of semiconductors used in all electronic devices. ---> India is the 4th largest economy in the world. India has a huge population of 1.4 billion people making it the world's most populated country surpassing China.
#
# ...
